# %%
import open3d as o3d
import numpy as np
import os
import sys
import math
import pandas as pd
from matplotlib import pylab
import itertools
from matplotlib import pyplot as plt
from statistics import mean

# %%
path = ("./3D Point Cloud Dataset/")
mylist = os.listdir(path)

mylist
# Out:
# ['1-3.95.ply',
#  '10-4.84.ply',
#  '11-4.48.ply',
#  '12-3.70.ply',
#  '13-6.63.ply',
#  '14-2.67.ply',
#  '15-4.99.ply',
#  '16-4.50.ply',
#  '17-4.98.ply',
#  '18-5.02.ply',
#  '19-3.34.ply',
#  '2-6.47.ply',
#  '20-4.39.ply',
#  '21-3.93.ply',
#  '22-4.81.ply',
#  '23-4.59.ply',
#  '24-5.12.ply',
#  '25-4.35.ply',
#  '26-2.53.ply',
#  '27-3.14.ply',
#  '28-3.49.ply',
#  '29-1.80.ply',
#  '3-7.71.ply',
#  '30-3.13.ply',
#  '4-5.58.ply',
#  '5-5.15.ply',
#  '6-4.46.ply',
#  '7-4.52.ply',
#  '8-5.23.ply',
#  '9-3.23.ply']

# %%
df = pd.DataFrame()
df = pd.DataFrame(columns = ['Name', 'Real Height', 'Pixel Height'])

for i in mylist:
    name = i[:-9]
    height = float(i[-8:-4])
    
    pcd = o3d.io.read_point_cloud(str("../tree/coconut/") + i)
    cl, ind = pcd.remove_statistical_outlier(nb_neighbors=300, std_ratio=2.0)
    lowest_pixel = o3d.geometry.PointCloud.get_min_bound(cl)[2]
    heighest_pixel = o3d.geometry.PointCloud.get_max_bound(pcd)[2]
    
    
    df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
        ignore_index = True)
    
df.to_csv('./data_tree.csv')
# Out:
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},
# C:\Users\NIK\AppData\Local\Temp\ipykernel_17488\2431965777.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name' : name, 'Real Height' : height, 'Pixel Height' : heighest_pixel - lowest_pixel},

# %%
print("Scatter Plot:  ")
plt.scatter(df["Pixel Height"] , df["Real Height"])
# Out:
# Scatter Plot:

# %%
df
# Out:
#    Name  Real Height  Pixel Height
# 0     1         3.95      3.991000
# 1    10         4.84      4.969000
# 2    11         4.48      4.801001
# 3    12         3.70      3.720000
# 4    13         6.63      7.049000
# 5    14         2.67      2.927001
# 6    15         4.99      5.164000
# 7    16         4.50      4.728000
# 8    17         4.98      5.268000
# 9    18         5.02      5.115000
# 10   19         3.34      3.595000
# 11    2         6.47      6.568000
# 12   20         4.39      4.438000
# 13   21         3.93      4.270000
# 14   22         4.81      4.921999
# 15   23         4.59      4.894001
# 16   24         5.12      5.191000
# 17   25         4.35      4.566000
# 18   26         2.53      2.779000
# 19   27         3.14      3.183000
# 20   28         3.49      3.488000
# 21   29         1.80      1.886000
# 22    3         7.71      7.988000
# 23   30         3.13      3.168000
# 24    4         5.58      5.708000
# 25    5         5.15      5.174000
# 26    6         4.46      4.540000
# 27    7         4.52      4.458000
# 28    8         5.23      5.238000
# 29    9         3.23      3.250000

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.3)

# %%
# Out:
#    Name  Real Height  Pixel Height  Predict Height   Accuracy     Error
# 0     1         3.95      3.991000        3.849425  97.453803 -0.100575
# 1    10         4.84      4.969000        4.806542  99.308711 -0.033458
# 2    11         4.48      4.801001        4.642130  96.381035  0.162130
# 3    12         3.70      3.720000        3.584212  96.870582 -0.115788
# 4    13         6.63      7.049000        6.842128  96.800490  0.212128
# 5    14         2.67      2.927001        2.808145  94.826020  0.138145
# 6    15         4.99      5.164000        4.997378  99.852146  0.007378
# 7    16         4.50      4.728000        4.570688  98.429166  0.070688
# 8    17         4.98      5.268000        5.099157  97.607293  0.119157
# 9    18         5.02      5.115000        4.949424  98.594103 -0.070576
# 10   19         3.34      3.595000        3.461881  96.350878  0.121881
# 11    2         6.47      6.568000        6.371398  98.476019 -0.098602
# 12   20         4.39      4.438000        4.286880  97.651024 -0.103120
# 13   21         3.93      4.270000        4.122468  95.102607  0.192468
# 14   22         4.81      4.921999        4.760545  98.971825 -0.049455
# 15   23         4.59      4.894001        4.733144  96.881400  0.143144
# 16   24         5.12      5.191000        5.023801  98.121120 -0.096199
# 17   25         4.35      4.566000        4.412147  98.571322  0.062147
# 18   26         2.53      2.779000        2.663305  94.731016  0.133305
# 19    3         7.71      7.988000        7.761077  99.337527  0.051077
# 20    4         5.58      5.708000        5.529762  99.099669 -0.050238
# 21    5         5.15      5.174000        5.007165  97.226497 -0.142835
# 22    6         4.46      4.540000        4.386702  98.356551 -0.073298
# 23    7         4.52      4.458000        4.306453  95.275517 -0.213547
# 24    8         5.23      5.238000        5.069798  96.936858 -0.160202
# 25    9         3.23      3.250000        3.124248  96.725935 -0.105752

# %%
from scipy import stats

slope, intercept, r, p, std_err = stats.linregress(train["Pixel Height"] , train["Real Height"])

# %%
print("Scatter Plot:  ")
plt.scatter(train["Pixel Height"] , train["Real Height"])
plt.plot(train["Pixel Height"], intercept + slope*train["Pixel Height"], 'r', label='fitted line')
# Out:
# Scatter Plot:

# %%
def linregress(x):
  return slope * x + intercept

# %%
total = 0
num = len(df["Pixel Height"])
test["Predict Height"] = np.nan
test["Accuracy"] = np.nan
test["Error"] = np.nan
for index, row in test.iterrows():
    
    predict = linregress(row["Pixel Height"])
    error_percent = abs((predict - row["Real Height"])/row["Real Height"]*100)
    accuracy = 100-error_percent
    error = abs((predict - row["Real Height"]))
    
    test.at[index,'Predict Height'] = predict
    test.at[index,'Accuracy'] = accuracy
    test.at[index,'Error'] = predict - row["Real Height"]
    
    print("%.3f" % accuracy)
#     print((predict - row["Real Height"])/row["Real Height"]*100)
        
    total += abs(error_percent)
    
print('')
avr = total/len(test["Pixel Height"])
print('Error Average')
print("%.3f" % avr)
#     print(abs(predict - row['real_height']))
#     print(100 - abs(predict/row['real_height']))
# Out:
# 98.027
# 96.416
# 99.412
# 97.090
# 98.989
# 99.343
# 98.211
# 93.507
# 95.889
#
# Error Average
# 2.569

# %%
df
# Out:
#    Name  Real Height  Pixel Height  Predict Height   Accuracy     Error
# 17   25         4.35      4.566000        4.435835  98.026780  0.085835
# 15   23         4.59      4.894001        4.754522  96.415634  0.164522
# 14   22         4.81      4.921999        4.781726  99.412191 -0.028274
# 20   28         3.49      3.488000        3.388442  97.090020 -0.101558
# 9    18         5.02      5.115000        4.969247  98.988983 -0.050753
# 22    3         7.71      7.988000        7.760675  99.342732  0.050675
# 12   20         4.39      4.438000        4.311469  98.211130 -0.078531
# 5    14         2.67      2.927001        2.843370  93.506723  0.173370
# 2    11         4.48      4.801001        4.664163  95.889219  0.184163

# %%
type(train["Pixel Height"])
# Out:
# pandas.core.series.Series

# %%
from sklearn import linear_model

training_data = train["Pixel Height"].to_numpy()

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import utils

#convert y values to categorical values

X_train, X_test, y_train, y_test = train_test_split(df.drop('Real Height', axis=1), df['Real Height'], test_size=0.3)  

lab = preprocessing.LabelEncoder()
y_train = lab.fit_transform(y_train)

# %%
logisticregression = linear_model.LogisticRegression()
logisticregression.fit(X_train['Pixel Height'].to_numpy().reshape(-1,1) , y_train)
# Out:
# LogisticRegression()

# %%
predict_logisticregression = logisticregression.predict(X_test['Pixel Height'].to_numpy().reshape(-1,1))

# %%
print(predict_logisticregression)
# Out:
# [19 20 20 14 19 18 11 19 19]

# %%
print(X_test)
# Out:
#    Name  Pixel Height
# 25    5      5.174000
# 4    13      7.049000
# 11    2      6.568000
# 26    6      4.540000
# 8    17      5.268000
# 2    11      4.801001
# 13   21      4.270000
# 1    10      4.969000
# 28    8      5.238000
